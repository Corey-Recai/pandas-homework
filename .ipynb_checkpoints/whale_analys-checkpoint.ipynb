# %%
# Import modules
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Ignore the SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %%
# Read whale_returns.csv data into DataFrame whl_df
whl_df = pd.read_csv ('Resources/whale_returns.csv')

# Count null values in whl_df
whl_df.isnull()
# Out:
#        Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     False                       True                True
# 1     False                      False               False
# 2     False                      False               False
# 3     False                      False               False
# 4     False                      False               False
# ...     ...                        ...                 ...
# 1055  False                      False               False
# 1056  False                      False               False
# 1057  False                      False               False
# 1058  False                      False               False
# 1059  False                      False               False
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                            True                    True
# 1                           False                   False
# 2                           False                   False
# 3                           False                   False
# 4                           False                   False
# ...                           ...                     ...
# 1055                        False                   False
# 1056                        False                   False
# 1057                        False                   False
# 1058                        False                   False
# 1059                        False                   False
#
# [1060 rows x 5 columns]

# %%
# Drop null values in whl_df
whl_df.dropna()
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# 5     2015-03-09                   0.000582            0.004225
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# 3                        0.002355                0.006726
# 4                       -0.008481               -0.013098
# 5                        0.005843               -0.001652
# ...                           ...                     ...
# 1055                    -0.005153                0.004848
# 1056                     0.012355                0.010434
# 1057                     0.006251                0.005223
# 1058                    -0.000259               -0.003702
# 1059                    -0.007936               -0.007833
#
# [1059 rows x 5 columns]

# %%
# Remove '.' from 'PAULSON & CO.INC.'
whl_df.rename(columns={whl_df.columns[2]:'PAULSON & CO INC'}, inplace=True)

# %%
# Convert whl_df 'Date' column to datetime
whl_df['Date'] = pd.to_datetime(whl_df['Date'])

# %%
# Sort the values of whl_df by 'Date' column in ascending order
whl_df.sort_values(by=['Date'],inplace=True)
whl_df
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# 0    2015-03-02                        NaN               NaN
# 1    2015-03-03                  -0.001266         -0.004981
# 2    2015-03-04                   0.002230          0.003241
# 3    2015-03-05                   0.004016          0.004076
# 4    2015-03-06                  -0.007905         -0.003574
# ...         ...                        ...               ...
# 1055 2019-04-25                  -0.000285         -0.001291
# 1056 2019-04-26                   0.008149          0.009162
# 1057 2019-04-29                   0.001254          0.002719
# 1058 2019-04-30                  -0.001295         -0.002211
# 1059 2019-05-01                  -0.005847         -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# 3                        0.002355                0.006726
# 4                       -0.008481               -0.013098
# ...                           ...                     ...
# 1055                    -0.005153                0.004848
# 1056                     0.012355                0.010434
# 1057                     0.006251                0.005223
# 1058                    -0.000259               -0.003702
# 1059                    -0.007936               -0.007833
#
# [1060 rows x 5 columns]

# %%
# Set the range of Dates to 2015-03-02 through 2019-04-23
whl_df_lkup = (whl_df['Date'] > '2015-03-02') & (whl_df['Date'] <= '2019-04-08')
whl_df = whl_df.loc[whl_df_lkup]
whl_df
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# 1    2015-03-03                  -0.001266         -0.004981
# 2    2015-03-04                   0.002230          0.003241
# 3    2015-03-05                   0.004016          0.004076
# 4    2015-03-06                  -0.007905         -0.003574
# 5    2015-03-09                   0.000582          0.004225
# ...         ...                        ...               ...
# 1039 2019-04-02                   0.000193         -0.005619
# 1040 2019-04-03                   0.003562          0.001305
# 1041 2019-04-04                   0.001255          0.010630
# 1042 2019-04-05                   0.006880          0.006484
# 1043 2019-04-08                   0.000483         -0.000310
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# 3                        0.002355                0.006726
# 4                       -0.008481               -0.013098
# 5                        0.005843               -0.001652
# ...                           ...                     ...
# 1039                    -0.006623                0.001152
# 1040                     0.005193                0.003252
# 1041                     0.008459               -0.008037
# 1042                     0.009357                0.006128
# 1043                     0.000153                0.000841
#
# [1043 rows x 5 columns]

# %%
# Reset the index of whl_df and drop 'index' column
whl_df.reset_index(inplace=True)
whl_df.drop(columns=['index'], inplace=True)
whl_df
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# 0    2015-03-03                  -0.001266         -0.004981
# 1    2015-03-04                   0.002230          0.003241
# 2    2015-03-05                   0.004016          0.004076
# 3    2015-03-06                  -0.007905         -0.003574
# 4    2015-03-09                   0.000582          0.004225
# ...         ...                        ...               ...
# 1038 2019-04-02                   0.000193         -0.005619
# 1039 2019-04-03                   0.003562          0.001305
# 1040 2019-04-04                   0.001255          0.010630
# 1041 2019-04-05                   0.006880          0.006484
# 1042 2019-04-08                   0.000483         -0.000310
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                       -0.000496               -0.006569
# 1                       -0.002534                0.004213
# 2                        0.002355                0.006726
# 3                       -0.008481               -0.013098
# 4                        0.005843               -0.001652
# ...                           ...                     ...
# 1038                    -0.006623                0.001152
# 1039                     0.005193                0.003252
# 1040                     0.008459               -0.008037
# 1041                     0.009357                0.006128
# 1042                     0.000153                0.000841
#
# [1043 rows x 5 columns]

# %%
# Read sp500_history.csv into DataFrame sp_df
sp_df = pd.read_csv('Resources/sp500_history.csv')

# %%
# Check Data Types in sp_df
sp_df.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Convert sp_df 'Date' column to datetime
sp_df['Date'] = pd.to_datetime(sp_df['Date'])

# Remove '$' from 'Close' column and convert to float
sp_df['Close'] = sp_df['Close'].str.replace('$', '').astype(float)

# %%
# Sort the values of sp_df by 'Date' column in ascending order
sp_df.sort_values(by=['Date'],inplace=True)
sp_df
# Out:
#            Date    Close
# 1648 2012-10-01  1444.49
# 1647 2012-10-02  1445.75
# 1646 2012-10-03  1450.99
# 1645 2012-10-04  1461.40
# 1644 2012-10-05  1460.93
# ...         ...      ...
# 4    2019-04-16  2907.06
# 3    2019-04-17  2900.45
# 2    2019-04-18  2905.03
# 1    2019-04-22  2907.97
# 0    2019-04-23  2933.68
#
# [1649 rows x 2 columns]

# %%
# Set the range of Dates to 2015-03-02 through 2019-04-23
sp_df_lkup = (sp_df['Date'] > '2015-03-01') & (sp_df['Date'] <= '2019-04-23')
sp_df = sp_df.loc[sp_df_lkup]
sp_df
# Out:
#            Date    Close
# 1043 2015-03-02  2117.39
# 1042 2015-03-03  2107.78
# 1041 2015-03-04  2098.53
# 1040 2015-03-05  2101.04
# 1039 2015-03-06  2071.26
# ...         ...      ...
# 4    2019-04-16  2907.06
# 3    2019-04-17  2900.45
# 2    2019-04-18  2905.03
# 1    2019-04-22  2907.97
# 0    2019-04-23  2933.68
#
# [1044 rows x 2 columns]

# %%
# Reset the index of sp_df and drop 'index' column
sp_df.reset_index(inplace=True)
sp_df.drop(columns=['index'], inplace=True)
sp_df
# Out:
#            Date    Close
# 0    2015-03-02  2117.39
# 1    2015-03-03  2107.78
# 2    2015-03-04  2098.53
# 3    2015-03-05  2101.04
# 4    2015-03-06  2071.26
# ...         ...      ...
# 1039 2019-04-16  2907.06
# 1040 2019-04-17  2900.45
# 1041 2019-04-18  2905.03
# 1042 2019-04-22  2907.97
# 1043 2019-04-23  2933.68
#
# [1044 rows x 2 columns]

# %%
# Calculate Daily Returns of sp_df
close_px = sp_df['Close']
sp_dly_ret = close_px / close_px.shift(1) - 1

# Append Daily Returns sp_dly_ret to new column in sp_df named 'S&P 500'
sp_df['S&P 500'] = sp_dly_ret

# Drop nulls from sp_df
sp_df.dropna()

# Drop Column 'Close' from sp_df
sp_df.drop(columns=['Close'], inplace=True)
sp_df
# Out:
#            Date   S&P 500
# 0    2015-03-02       NaN
# 1    2015-03-03 -0.004539
# 2    2015-03-04 -0.004389
# 3    2015-03-05  0.001196
# 4    2015-03-06 -0.014174
# ...         ...       ...
# 1039 2019-04-16  0.000509
# 1040 2019-04-17 -0.002274
# 1041 2019-04-18  0.001579
# 1042 2019-04-22  0.001012
# 1043 2019-04-23  0.008841
#
# [1044 rows x 2 columns]

# %%
# Drop first row, reset index and rename 'Date' column to 'Date_1'
sp_df.drop(sp_df.index[0], inplace=True)
sp_df.reset_index(inplace=True)
sp_df.drop(columns=['index'], inplace=True)
sp_df.rename(columns={'Date':'Date_1'}, inplace=True)
sp_df
# Out:
#          Date_1   S&P 500
# 0    2015-03-03 -0.004539
# 1    2015-03-04 -0.004389
# 2    2015-03-05  0.001196
# 3    2015-03-06 -0.014174
# 4    2015-03-09  0.003944
# ...         ...       ...
# 1038 2019-04-16  0.000509
# 1039 2019-04-17 -0.002274
# 1040 2019-04-18  0.001579
# 1041 2019-04-22  0.001012
# 1042 2019-04-23  0.008841
#
# [1043 rows x 2 columns]

# %%
# Read algo_returns.csv data into DataFrame algo_df
algo_df = pd.read_csv('Resources/algo_returns.csv')
algo_df
# Out:
#             Date    Algo 1    Algo 2
# 0     2014-05-28  0.001745       NaN
# 1     2014-05-29  0.003978       NaN
# 2     2014-05-30  0.004464       NaN
# 3     2014-06-02  0.005692       NaN
# 4     2014-06-03  0.005292       NaN
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %%
# Convert algo_df 'Date' column to datetime
algo_df['Date'] = pd.to_datetime(algo_df['Date'])

# %%
# Sort the values of algo_df by 'Date' column in ascending order
algo_df.sort_values(by=['Date'],inplace=True)
algo_df
# Out:
#            Date    Algo 1    Algo 2
# 0    2014-05-28  0.001745       NaN
# 1    2014-05-29  0.003978       NaN
# 2    2014-05-30  0.004464       NaN
# 3    2014-06-02  0.005692       NaN
# 4    2014-06-03  0.005292       NaN
# ...         ...       ...       ...
# 1236 2019-04-25  0.000682 -0.007247
# 1237 2019-04-26  0.002981  0.005256
# 1238 2019-04-29  0.005208  0.002829
# 1239 2019-04-30 -0.002944 -0.001570
# 1240 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %%
# Set the range of Dates to 2015-03-02 through 2019-04-23
algo_df_lkup = (algo_df['Date'] > '2015-03-02') & (algo_df['Date'] <= '2019-04-23')
algo_df = algo_df.loc[algo_df_lkup]
algo_df
# Out:
#            Date    Algo 1    Algo 2
# 192  2015-03-03 -0.001942 -0.000949
# 193  2015-03-04 -0.008589  0.002416
# 194  2015-03-05 -0.000955  0.004323
# 195  2015-03-06 -0.004957 -0.011460
# 196  2015-03-09 -0.005447  0.001303
# ...         ...       ...       ...
# 1230 2019-04-16 -0.006945  0.002899
# 1231 2019-04-17 -0.010301 -0.005228
# 1232 2019-04-18 -0.000588 -0.001229
# 1233 2019-04-22  0.000677 -0.001936
# 1234 2019-04-23  0.004969  0.009622
#
# [1043 rows x 3 columns]

# %%
# Reset the index of sp_df and drop 'index' column and rename 'Date' column to 'Date_2'
algo_df.reset_index(inplace=True)
algo_df.drop(columns=['index'], inplace=True)
algo_df.rename(columns={'Date':'Date_2'}, inplace=True)
algo_df
# Out:
#          Date_2    Algo 1    Algo 2
# 0    2015-03-03 -0.001942 -0.000949
# 1    2015-03-04 -0.008589  0.002416
# 2    2015-03-05 -0.000955  0.004323
# 3    2015-03-06 -0.004957 -0.011460
# 4    2015-03-09 -0.005447  0.001303
# ...         ...       ...       ...
# 1038 2019-04-16 -0.006945  0.002899
# 1039 2019-04-17 -0.010301 -0.005228
# 1040 2019-04-18 -0.000588 -0.001229
# 1041 2019-04-22  0.000677 -0.001936
# 1042 2019-04-23  0.004969  0.009622
#
# [1043 rows x 3 columns]

# %%
# Combine Whale, Algorithmic and S&P 500 Returns into single DataFrame
ret_df = pd.concat([whl_df, algo_df, sp_df], axis="columns", join="inner")
ret_df
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# 0    2015-03-03                  -0.001266         -0.004981
# 1    2015-03-04                   0.002230          0.003241
# 2    2015-03-05                   0.004016          0.004076
# 3    2015-03-06                  -0.007905         -0.003574
# 4    2015-03-09                   0.000582          0.004225
# ...         ...                        ...               ...
# 1038 2019-04-02                   0.000193         -0.005619
# 1039 2019-04-03                   0.003562          0.001305
# 1040 2019-04-04                   0.001255          0.010630
# 1041 2019-04-05                   0.006880          0.006484
# 1042 2019-04-08                   0.000483         -0.000310
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC     Date_2  \
# 0                       -0.000496               -0.006569 2015-03-03
# 1                       -0.002534                0.004213 2015-03-04
# 2                        0.002355                0.006726 2015-03-05
# 3                       -0.008481               -0.013098 2015-03-06
# 4                        0.005843               -0.001652 2015-03-09
# ...                           ...                     ...        ...
# 1038                    -0.006623                0.001152 2019-04-16
# 1039                     0.005193                0.003252 2019-04-17
# 1040                     0.008459               -0.008037 2019-04-18
# 1041                     0.009357                0.006128 2019-04-22
# 1042                     0.000153                0.000841 2019-04-23
#
#         Algo 1    Algo 2     Date_1   S&P 500
# 0    -0.001942 -0.000949 2015-03-03 -0.004539
# 1    -0.008589  0.002416 2015-03-04 -0.004389
# 2    -0.000955  0.004323 2015-03-05  0.001196
# 3    -0.004957 -0.011460 2015-03-06 -0.014174
# 4    -0.005447  0.001303 2015-03-09  0.003944
# ...        ...       ...        ...       ...
# 1038 -0.006945  0.002899 2019-04-16  0.000509
# 1039 -0.010301 -0.005228 2019-04-17 -0.002274
# 1040 -0.000588 -0.001229 2019-04-18  0.001579
# 1041  0.000677 -0.001936 2019-04-22  0.001012
# 1042  0.004969  0.009622 2019-04-23  0.008841
#
# [1043 rows x 10 columns]

# %%
# Compare Date columns to find where dates do not match
ret_df.loc[ret_df['Date'] < ret_df['Date_1']]
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# 86   2015-07-03                   0.000000          0.000000
# 87   2015-07-06                  -0.005870         -0.002186
# 88   2015-07-07                   0.000597          0.003962
# 89   2015-07-08                  -0.017211         -0.007654
# 90   2015-07-09                   0.007472          0.003887
# ...         ...                        ...               ...
# 1038 2019-04-02                   0.000193         -0.005619
# 1039 2019-04-03                   0.003562          0.001305
# 1040 2019-04-04                   0.001255          0.010630
# 1041 2019-04-05                   0.006880          0.006484
# 1042 2019-04-08                   0.000483         -0.000310
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC     Date_2  \
# 86                       0.000000                0.000000 2015-07-06
# 87                      -0.001083               -0.005799 2015-07-07
# 88                       0.004652               -0.007634 2015-07-08
# 89                      -0.014788               -0.011737 2015-07-09
# 90                       0.000441                0.017670 2015-07-10
# ...                           ...                     ...        ...
# 1038                    -0.006623                0.001152 2019-04-16
# 1039                     0.005193                0.003252 2019-04-17
# 1040                     0.008459               -0.008037 2019-04-18
# 1041                     0.009357                0.006128 2019-04-22
# 1042                     0.000153                0.000841 2019-04-23
#
#         Algo 1    Algo 2     Date_1   S&P 500
# 86   -0.014638 -0.004958 2015-07-06 -0.003862
# 87   -0.004611 -0.002519 2015-07-07  0.006081
# 88   -0.013853 -0.015528 2015-07-08 -0.016653
# 89    0.014090  0.003624 2015-07-09  0.002262
# 90    0.003362  0.014381 2015-07-10  0.012338
# ...        ...       ...        ...       ...
# 1038 -0.006945  0.002899 2019-04-16  0.000509
# 1039 -0.010301 -0.005228 2019-04-17 -0.002274
# 1040 -0.000588 -0.001229 2019-04-18  0.001579
# 1041  0.000677 -0.001936 2019-04-22  0.001012
# 1042  0.004969  0.009622 2019-04-23  0.008841
#
# [957 rows x 10 columns]

# %%
# Drop the rows where the dates do not match
ret_df.drop(ret_df.index[86:1043], inplace=True)
ret_df
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# 0  2015-03-03                  -0.001266         -0.004981
# 1  2015-03-04                   0.002230          0.003241
# 2  2015-03-05                   0.004016          0.004076
# 3  2015-03-06                  -0.007905         -0.003574
# 4  2015-03-09                   0.000582          0.004225
# ..        ...                        ...               ...
# 81 2015-06-26                  -0.010598         -0.004986
# 82 2015-06-29                  -0.019129         -0.006835
# 83 2015-06-30                   0.006073          0.001550
# 84 2015-07-01                  -0.001365          0.002100
# 85 2015-07-02                   0.000613         -0.000139
#
#     TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC     Date_2    Algo 1  \
# 0                     -0.000496               -0.006569 2015-03-03 -0.001942
# 1                     -0.002534                0.004213 2015-03-04 -0.008589
# 2                      0.002355                0.006726 2015-03-05 -0.000955
# 3                     -0.008481               -0.013098 2015-03-06 -0.004957
# 4                      0.005843               -0.001652 2015-03-09 -0.005447
# ..                          ...                     ...        ...       ...
# 81                     0.003986               -0.005103 2015-06-26  0.003362
# 82                    -0.019384               -0.019997 2015-06-29  0.000903
# 83                     0.004071                0.011826 2015-06-30  0.002524
# 84                     0.005815               -0.001304 2015-07-01 -0.007847
# 85                    -0.001781               -0.009721 2015-07-02 -0.002005
#
#       Algo 2     Date_1   S&P 500
# 0  -0.000949 2015-03-03 -0.004539
# 1   0.002416 2015-03-04 -0.004389
# 2   0.004323 2015-03-05  0.001196
# 3  -0.011460 2015-03-06 -0.014174
# 4   0.001303 2015-03-09  0.003944
# ..       ...        ...       ...
# 81 -0.002704 2015-06-26 -0.000390
# 82 -0.023736 2015-06-29 -0.020866
# 83  0.007395 2015-06-30  0.002658
# 84  0.002724 2015-07-01  0.006936
# 85 -0.005172 2015-07-02 -0.000308
#
# [86 rows x 10 columns]

# %%
# Drop the 'Date_1' and 'Date_2' columns
ret_df.drop(columns=['Date_1','Date_2'], inplace=True)
ret_df
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# 0  2015-03-03                  -0.001266         -0.004981
# 1  2015-03-04                   0.002230          0.003241
# 2  2015-03-05                   0.004016          0.004076
# 3  2015-03-06                  -0.007905         -0.003574
# 4  2015-03-09                   0.000582          0.004225
# ..        ...                        ...               ...
# 81 2015-06-26                  -0.010598         -0.004986
# 82 2015-06-29                  -0.019129         -0.006835
# 83 2015-06-30                   0.006073          0.001550
# 84 2015-07-01                  -0.001365          0.002100
# 85 2015-07-02                   0.000613         -0.000139
#
#     TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# 0                     -0.000496               -0.006569 -0.001942 -0.000949
# 1                     -0.002534                0.004213 -0.008589  0.002416
# 2                      0.002355                0.006726 -0.000955  0.004323
# 3                     -0.008481               -0.013098 -0.004957 -0.011460
# 4                      0.005843               -0.001652 -0.005447  0.001303
# ..                          ...                     ...       ...       ...
# 81                     0.003986               -0.005103  0.003362 -0.002704
# 82                    -0.019384               -0.019997  0.000903 -0.023736
# 83                     0.004071                0.011826  0.002524  0.007395
# 84                     0.005815               -0.001304 -0.007847  0.002724
# 85                    -0.001781               -0.009721 -0.002005 -0.005172
#
#      S&P 500
# 0  -0.004539
# 1  -0.004389
# 2   0.001196
# 3  -0.014174
# 4   0.003944
# ..       ...
# 81 -0.000390
# 82 -0.020866
# 83  0.002658
# 84  0.006936
# 85 -0.000308
#
# [86 rows x 8 columns]

# %%
# Set index of ret_df to 'Date' column
ret_df.set_index(['Date'], inplace=True)
ret_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# Date
# 2015-03-03                  -0.001266         -0.004981
# 2015-03-04                   0.002230          0.003241
# 2015-03-05                   0.004016          0.004076
# 2015-03-06                  -0.007905         -0.003574
# 2015-03-09                   0.000582          0.004225
# ...                               ...               ...
# 2015-06-26                  -0.010598         -0.004986
# 2015-06-29                  -0.019129         -0.006835
# 2015-06-30                   0.006073          0.001550
# 2015-07-01                  -0.001365          0.002100
# 2015-07-02                   0.000613         -0.000139
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2015-06-26                     0.003986               -0.005103  0.003362
# 2015-06-29                    -0.019384               -0.019997  0.000903
# 2015-06-30                     0.004071                0.011826  0.002524
# 2015-07-01                     0.005815               -0.001304 -0.007847
# 2015-07-02                    -0.001781               -0.009721 -0.002005
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944
# ...              ...       ...
# 2015-06-26 -0.002704 -0.000390
# 2015-06-29 -0.023736 -0.020866
# 2015-06-30  0.007395  0.002658
# 2015-07-01  0.002724  0.006936
# 2015-07-02 -0.005172 -0.000308
#
# [86 rows x 7 columns]

# %%
# Plot daily returns of ret_df
dly_ret = ret_df.pct_change()
dly_ret.plot(figsize=(20, 10))

# %%
# Plot cummulative returns of ret_df
cum_ret = (1 + ret_df).cumprod()
cum_ret.plot(figsize=(20, 10))

# %%
# Create a box plot for ret_df
ret_df.plot(kind="box", figsize=(20, 10))

# %%
# Calculate daily standard deviation for ret_df and determite which stocks are riskiest
dly_rsk = ret_df.std()
dly_rsk.sort_values(inplace=True)
dly_rsk
# Out:
# PAULSON & CO INC               0.003725
# SOROS FUND MANAGEMENT LLC      0.005301
# Algo 1                         0.005472
# TIGER GLOBAL MANAGEMENT LLC    0.005637
# Algo 2                         0.006094
# BERKSHIRE HATHAWAY INC         0.006707
# S&P 500                        0.007064
# dtype: float64

# %%
# Calculate annualized standard deviation for ret_df and determine which stocks are riskiest
yrly_rsk = ret_df.std() * np.sqrt(252)
yrly_rsk.sort_values(inplace=True)
yrly_rsk
# Out:
# PAULSON & CO INC               0.059125
# SOROS FUND MANAGEMENT LLC      0.084155
# Algo 1                         0.086871
# TIGER GLOBAL MANAGEMENT LLC    0.089478
# Algo 2                         0.096736
# BERKSHIRE HATHAWAY INC         0.106466
# S&P 500                        0.112132
# dtype: float64

# %%
# Calculate the rolling standard deviation for S&P 500 using 21 day window
sp_rstd_21 = ret_df['S&P 500'].rolling(window=21).std()
sp_rstd_21
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2015-06-26    0.005683
# 2015-06-29    0.007138
# 2015-06-30    0.007153
# 2015-07-01    0.007364
# 2015-07-02    0.007336
# Name: S&P 500, Length: 86, dtype: float64

# %%
# Plot rolling standard deviation
sp_rstd_21.plot(kind='bar',figsize=(30, 10))

# %%
# Calculate correlation bwteen portfolios if ret_df
corr_df = ret_df.corr()
corr_df
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO INC  \
# SOROS FUND MANAGEMENT LLC                     1.000000          0.734943
# PAULSON & CO INC                              0.734943          1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.820352          0.718552
# BERKSHIRE HATHAWAY INC                        0.801077          0.672580
# Algo 1                                        0.165893          0.035260
# Algo 2                                        0.816102          0.696653
# S&P 500                                       0.829286          0.688689
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.820352
# PAULSON & CO INC                                0.718552
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.760252
# Algo 1                                          0.116752
# Algo 2                                          0.857404
# S&P 500                                         0.926824
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.801077  0.165893  0.816102
# PAULSON & CO INC                           0.672580  0.035260  0.696653
# TIGER GLOBAL MANAGEMENT LLC                0.760252  0.116752  0.857404
# BERKSHIRE HATHAWAY INC                     1.000000  0.110380  0.789981
# Algo 1                                     0.110380  1.000000  0.023360
# Algo 2                                     0.789981  0.023360  1.000000
# S&P 500                                    0.735909  0.130725  0.867789
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.829286
# PAULSON & CO INC             0.688689
# TIGER GLOBAL MANAGEMENT LLC  0.926824
# BERKSHIRE HATHAWAY INC       0.735909
# Algo 1                       0.130725
# Algo 2                       0.867789
# S&P 500                      1.000000

# %%
# Plot heatmap for correlation of ret_df
plt.subplots(figsize=(20, 10))
sns.heatmap(corr_df, vmin=-1, vmax=1)

# %%
# Calculate Beta for portfolios compared to S&P 500

# Calculate covariance of portfolios vs. S&P 500
srs_cov = ret_df['SOROS FUND MANAGEMENT LLC'].cov(ret_df['S&P 500'])
plsn_cov = ret_df['PAULSON & CO INC'].cov(ret_df['S&P 500'])
tgm_cov = ret_df['TIGER GLOBAL MANAGEMENT LLC'].cov(ret_df['S&P 500'])
bkh_cov = ret_df['BERKSHIRE HATHAWAY INC'].cov(ret_df['S&P 500'])
algo1_cov = ret_df['Algo 1'].cov(ret_df['S&P 500'])
algo2_cov = ret_df['Algo 2'].cov(ret_df['S&P 500'])

# Calculate variance of S&P 500
sp_var = ret_df['S&P 500'].var()

# Calculate Betas and print results
srs_bta = srs_cov / sp_var
plsn_bta = plsn_cov / sp_var
tgm_bta = tgm_cov / sp_var
bkh_bta = bkh_cov / sp_var
algo1_bta = algo1_cov / sp_var
algo2_bta = algo2_cov / sp_var

print(f"Soros Fund Management LLC - Beta: {srs_bta} \n"
      f"Paulson & Co Inc - Beta: {plsn_bta} \n"
      f"Tiger Global Management LLC - Beta: {tgm_bta} \n"
      f"Berkshire Hataway Inc - Beta: {bkh_bta} \n"
      f"Algo 1 - Beta: {algo1_bta} \n"
      f"Algo 2 - Beta: {algo2_bta}"
     )
# Out:
# Soros Fund Management LLC - Beta: 0.6223801093468933
# Paulson & Co Inc - Beta: 0.36313141679057204
# Tiger Global Management LLC - Beta: 0.7395807935353214
# Berkshire Hataway Inc - Beta: 0.6987260220790783
# Algo 1 - Beta: 0.1012756845468214
# Algo 2 - Beta: 0.7486349317990558

# %%
# Calculate and plot bar chart for sharpe ratios for ret_df
ret_diff = ret_df.diff()
sr_ret = ret_diff.mean()/ret_diff.std() * np.sqrt(252)
sr_ret.plot(kind='bar',figsize=(20, 10))
